# %% [markdown]
# ## Starting Off
#
# Message me one question you have about APIs. Any question at all

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a search of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url =  'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = ____
api_key = ____
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-da4093659449> in <module>
# ----> 1 client_id = ____
#       2 api_key = ____
#
# NameError: name '____' is not defined

# %%
from  keys  import  client_id, api_key

# %%
print(api_key)
# Out:
# 7Y9_AJxCRZODCh-ltNRyXKnetWfEbh9IukEMhXM1bGMeNpgl3Xpr1f5nwAIuj2wLKNilp770vvggIP1fW1uFc26-YolKbvCjf6b8GrWLee-fY3yaxwU3uUGdW0nzX3Yx

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'Italian'

#where do you want to perform this search
location = 'West Village'

# what is your other parameter you want to search against
price = '1,2,3,4'

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "price" : price ,
                "limit": 50
            }

# %%
url_params
# Out:
# {'term': 'Italian',
#  'location': 'West+Village',
#  'price': '1,2,3,4',
#  'limit': 50}

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %%
response.status
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-f75033194368> in <module>
# ----> 1 response.status
#
# AttributeError: 'Response' object has no attribute 'status'

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
response.text
# Out:
# '{"businesses": [{"id": "rp8S7scxOkVVeG7dNneMGQ", "alias": "l-artusi-new-york", "name": "L\'Artusi", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/HeDloBW-SnokWblGDuPrUQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/l-artusi-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ", "review_count": 1862, "categories": [{"alias": "italian", "title": "Italian"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.73372, "longitude": -74.00513}, "transactions": ["delivery", "pickup"], "price": "$$$", "location": {"address1": "228 W 10th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10014", "country": "US", "state": "NY", "display_address": ["228 W 10th St", "New York, NY 10014"]}, "phone": "+12122555757", "display_phone": "(212) 255-5757", "distance": 235.00483236552975}, {"id": "h37t9rA06Sr4EetJjKrfzw", "alias": "don-angie-new-york", "name": "Don Angie", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/u-XgISAco-BBpUpuFrzJwQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/don-angie-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ", "review_count": 356, "categories": [{"alias": "italian", "title": "Italian"}, {"alias": "newamerican", "title": "American (New)"}], "rating": 4.5, "coordinates": {"latitude": 40.73778, "longitude": -74.00197}, "transactions": ["delivery"], "price": "$$$", "location": {"address1": "103 Greenwich Ave", "address2": "", "address3": null, "city": "New York", "zip_code": "10014", "country": "US", "state": "NY", "display_address": ["103 Greenwich Ave", "New York, NY 10014"]}, "phone": "+12128898884", "display_phone": "(212) 889-8884", "distance": 287.8085574655449}, {"id": "16ZnHpuaaBt92XWeJHCC5A", "alias": "olio-e-pi\\u00fa-new-york-5", "name": "Olio e Pi\\u00fa", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/zfMdQW5StR08SPg96JWy8g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/olio-e-pi%C3%BA-new-york-5?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ", "review_count": 2328, "categories": [{"alias": "pizza", "title": "Pizza"}, {"alias": "italian", "title": "Italian"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}], "rating": 4.5, "coordinates": {"latitude": 40.733826, "longitude": -73.999852}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "3 Greenwich Ave", "address2": null, "address3": "", "city": "New York", "zip_code": "10014", "country": "US", "state": "NY", "display_address": ["3 Greenwich Ave", "New York, NY 10014"]}, "phone": "+12122436546", "display_phone": "(212) 243-6546", "distance": 379.20450703107264}, {"id": "hdiuRS9sVZSMReZm4oV5SA", "alias": "da-andrea-new-york", "name": "Da Andrea", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/p_nuRaEIirVvKl55KPrzgg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/da-andrea-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ", "review_count": 783, "categories": [{"alias": "tuscan", "title": "Tuscan"}], "rating": 4.0, "coordinates": {"latitude": 40.736218, "longitude": -73.99597}, "transactions": ["restaurant_reservation", "delivery", "pickup"], "price": "$$", "location": {"address1": "35 W 13th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10011", "country": "US", "state": "NY", "display_address": ["35 W 13th St", "New York, NY 10011"]}, "phone": "+12123671979", "display_phone": "(212) 367-1979", "distance": 658.4009812926486}, {"id": "IErfGS0DASSJfYU73m0Sqg", "alias": "malatesta-trattoria-new-york", "name": "Malatesta Trattoria", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-5A2WyQ ...

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'rp8S7scxOkVVeG7dNneMGQ',
#    'alias': 'l-artusi-new-york',
#    'name': "L'Artusi",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HeDloBW-SnokWblGDuPrUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-artusi-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1862,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73372, 'longitude': -74.00513},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '228 W 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 W 10th St', 'New York, NY 10014']},
#    'phone': '+12122555757',
#    'display_phone': '(212) 255-5757',
#    'distance': 235.00483236552975},
#   {'id': 'h37t9rA06Sr4EetJjKrfzw',
#    'alias': 'don-angie-new-york',
#    'name': 'Don Angie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u-XgISAco-BBpUpuFrzJwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-angie-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 356,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73778, 'longitude': -74.00197},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '103 Greenwich Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 Greenwich Ave', 'New York, NY 10014']},
#    'phone': '+12128898884',
#    'display_phone': '(212) 889-8884',
#    'distance': 287.8085574655449},
#   {'id': '16ZnHpuaaBt92XWeJHCC5A',
#    'alias': 'olio-e-piú-new-york-5',
#    'name': 'Olio e Piú',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zfMdQW5StR08SPg96JWy8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olio-e-pi%C3%BA-new-york-5?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 2328,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733826, 'longitude': -73.999852},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3 Greenwich Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Greenwich Ave', 'New York, NY 10014']},
#    'phone': '+12122436546',
#    'display_phone': '(212) 243-6546',
#    'distance': 379.20450703107264},
#   {'id': 'hdiuRS9sVZSMReZm4oV5SA',
#    'alias': 'da-andrea-new-york',
#    'name': 'Da Andrea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p_nuRaEIirVvKl55KPrzgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-andrea-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 783,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.736218, 'longitude': -73.99597},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '35 W 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 W 13th St', 'New York, NY 10011']},
#    'phone': '+12123671979',
#    'display_phone': '(212) 367-1979',
#    'distance': 658.4009812926486},
#   {'id': 'IErfGS0DASSJfYU73m0Sqg',
#    'alias': 'malatesta-trattoria-new-york',
#    'name': 'Malatesta Trattoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-5A2WyQVd3xrzudn9JBLVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/malatesta-trattoria-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1248,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73285, 'longitude': -74.00847},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '649 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['649 Washington St', 'New York, NY 10014']},
#    'phone': '+12127411207',
#    'display_phone': '(212) 741-1207',
#    'distance': 497.3612080254306},
#   {'id': 'yZJbealagfujEkgesAl2hA',
#    'alias': 'lupa-new-york',
#    'name': 'Lupa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OdUK7zgusaMmPzToZuq3tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lupa-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1546,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7276, 'longitude': -74.000045},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '170 Thompson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 Thompson St', 'New York, NY 10012']},
#    'phone': '+12129825089',
#    'display_phone': '(212) 982-5089',
#    'distance': 930.7382369526371},
#   {'id': 'ZVa3-O6LMxZXSpKG0J1h-w',
#    'alias': 'piccolo-angolo-restaurant-new-york',
#    'name': 'Piccolo Angolo Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/q536opZ7gIL0oLxztUd2Gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccolo-angolo-restaurant-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 551,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7378601855952,
#     'longitude': -74.0058052539825},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '621 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['621 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122299177',
#    'display_phone': '(212) 229-9177',
#    'distance': 310.4573489731519},
#   {'id': 'qBGKigOGn_flCx1apxPzlA',
#    'alias': 'piccola-cucina-osteria-new-york',
#    'name': 'Piccola Cucina Osteria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U9CN5QUnEAp1tHKHM8ZrXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccola-cucina-osteria-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 571,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72506, 'longitude': -74.00322},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '196 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['196 Spring St', 'New York, NY 10012']},
#    'phone': '+16464787488',
#    'display_phone': '(646) 478-7488',
#    'distance': 1171.1830140013515},
#   {'id': 'jnHbdsqlTKlPcmJ8BCP9-g',
#    'alias': 'via-carota-new-york',
#    'name': 'Via Carota',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5EHi8MhocoDkXwMtL7o_ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/via-carota-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 586,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7331, 'longitude': -74.00369},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '51 Grove St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51 Grove St', 'New York, NY 10014']},
#    'phone': '+12122551962',
#    'display_phone': '(212) 255-1962',
#    'distance': 263.993966246553},
#   {'id': 'V-FCEicobl5Su-R7EVJQNA',
#    'alias': 'la-lanterna-di-vittorio-new-york',
#    'name': 'La Lanterna Di Vittorio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fniemSih6k-Gy103nmNVxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-lanterna-di-vittorio-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1466,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73069, 'longitude': -74.00015},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '129 MacDougal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['129 MacDougal St', 'New York, NY 10012']},
#    'phone': '+19176393236',
#    'display_phone': '(917) 639-3236',
#    'distance': 617.4476178465328},
#   {'id': 'ADHX7nBixDPVlq3OXhny0g',
#    'alias': 'faiccos-italian-specialties-new-york',
#    'name': "Faicco's Italian Specialties",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ecEFegMI5jPZbSI2QnndrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/faiccos-italian-specialties-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 540,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73113, 'longitude': -74.00306},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '260 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['260 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122431974',
#    'display_phone': '(212) 243-1974',
#    'distance': 493.7443742969898},
#   {'id': '_V7YsDQ4Lb41rqfkuPzm1w',
#    'alias': 'trattoria-pesce-pasta-new-york',
#    'name': 'Trattoria Pesce Pasta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FzapSuftE8tAd9kjpMo-Rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trattoria-pesce-pasta-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 246,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73115, 'longitude': -74.00319},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '262 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['262 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12126452993',
#    'display_phone': '(212) 645-2993',
#    'distance': 489.1306142055865},
#   {'id': 'YT5Ywu9y190B4IGIlBetzA',
#    'alias': 'morandi-new-york',
#    'name': 'Morandi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vJY1QKjGtO3noWUnshjEpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morandi-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 692,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73534, 'longitude': -74.00151},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '211 Waverly Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 Waverly Pl', 'New York, NY 10014']},
#    'phone': '+12126277575',
#    'display_phone': '(212) 627-7575',
#    'distance': 196.05652023672923},
#   {'id': '6Z5OWpaeGGazJHR4LfThsw',
#    'alias': 'palma-new-york',
#    'name': 'Palma',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KRhsHF7JmChZ5xrW5owiKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/palma-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 735,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73115, 'longitude': -74.00233},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '28 Cornelia St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Cornelia St', 'New York, NY 10014']},
#    'phone': '+12126912223',
#    'display_phone': '(212) 691-2223',
#    'distance': 498.88812125626464},
#   {'id': 'XfOa_KyrV7JSFJMOKckGMg',
#    'alias': 'montes-trattoria-new-york-2',
#    'name': "Monte's Trattoria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gjCsoro5Iyw7FhIOyMDR-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montes-trattoria-new-york-2?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 356,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72959, 'longitude': -74.0011},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '97 Macdougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12122289194',
#    'display_phone': '(212) 228-9194',
#    'distance': 694.1891183931191},
#   {'id': '15k7iqFbhf4h8L01yggLqg',
#    'alias': 'song-e-napule-new-york',
#    'name': 'Song E Napule',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y9G-nheTrxSrx4Cqg0HzHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/song-e-napule-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 499,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72813, 'longitude': -74.00188},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '146 W Houston St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 W Houston St', 'New York, NY 10012']},
#    'phone': '+12125331242',
#    'display_phone': '(212) 533-1242',
#    'distance': 834.6729873886403},
#   {'id': '7_hGsGEkHrjgAiYVjrCFnw',
#    'alias': 'carbone-new-york',
#    'name': 'Carbone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IPaDl6bzctnQOM6__ibOzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carbone-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1107,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728, 'longitude': -74.0001497},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '181 Thompson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Thompson St', 'New York, NY 10012']},
#    'phone': '+12122543000',
#    'display_phone': '(212) 254-3000',
#    'distance': 892.2844648923464},
#   {'id': '5Akss-swwfyoSVeIsDBbvw',
#    'alias': 'basta-pasta-new-york',
#    'name': 'Basta Pasta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_XGks_Id3-yCUzy-Spuw-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/basta-pasta-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1447,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73881, 'longitude': -73.99407},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '37 W 17th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 W 17th St', 'New York, NY 10011']},
#    'phone': '+12123660888',
#    'display_phone': '(212) 366-0888',
#    'distance': 893.6330169566667},
#   {'id': '-hUvO0C0A-pGZdiSKvjoFw',
#    'alias': 'babbo-new-york',
#    'name': 'Babbo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q5C3VQRIzsOoCGrZvjkFHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/babbo-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 2402,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732283, 'longitude': -73.999284},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '110 Waverly Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Waverly Pl', 'New York, NY 10011']},
#    'phone': '+12127770303',
#    'display_phone': '(212) 777-0303',
#    'distance': 522.1566838589547},
#   {'id': 'o5mMVFk4Hcpk2FuKfgTgdg',
#    'alias': 'malaparte-new-york',
#    'name': 'Malaparte',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2Ikz75YSTtVvPCDuMID8bA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/malaparte-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 329,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73687, 'longitude': -74.00812},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '753 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['753 Washington St', 'New York, NY 10014']},
#    'phone': '+12122552122',
#    'display_phone': '(212) 255-2122',
#    'distance': 395.8575488921887},
#   {'id': 'Vs8kQ4R381y27AH018gLpg',
#    'alias': 'supper-new-york',
#    'name': 'Supper',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jEEH9kmoHFmyQRgXiMjFuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/supper-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1312,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7229, 'longitude': -73.98527},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '156 E 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 E 2nd St', 'New York, NY 10009']},
#    'phone': '+12124777600',
#    'display_phone': '(212) 477-7600',
#    'distance': 2097.9482060458718},
#   {'id': 'dh5r9-SbN8xJ76XvnayWLQ',
#    'alias': 'giano-restaurant-new-york',
#    'name': 'Giano Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0PrOZ5stl86k6V1SzHcjNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giano-restaurant-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 611,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7262256596862,
#     'longitude': -73.9840574049125},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '126 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 E 7th St', 'New York, NY 10009']},
#    'phone': '+12126737200',
#    'display_phone': '(212) 673-7200',
#    'distance': 1955.560551684049},
#   {'id': 'J0OeDwmh5JBhid0A5GvltA',
#    'alias': 'il-corallo-trattoria-new-york',
#    'name': 'Il Corallo Trattoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GQZVMl-a6lIpu_ZnB5xcgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-corallo-trattoria-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 970,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7262073, 'longitude': -74.0018919},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '176 Prince St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 Prince St', 'New York, NY 10012']},
#    'phone': '+12129417119',
#    'display_phone': '(212) 941-7119',
#    'distance': 1050.4775288548224},
#   {'id': 'aJJlY5xvqS180wtRIHEWqA',
#    'alias': 'cotenna-new-york',
#    'name': 'Cotenna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A9FtedBK3bJGB7t-EeclJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cotenna-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 403,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72903, 'longitude': -74.00357},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '21 Bedford St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Bedford St', 'New York, NY 10014']},
#    'phone': '+16468610175',
#    'display_phone': '(646) 861-0175',
#    'distance': 727.7166967104224},
#   {'id': 'DtnlLLvcqeEUIyZTypHnzw',
#    'alias': 'il-mulino-new-york-downtown-new-york-2',
#    'name': 'Il Mulino New York - Downtown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IR-FDmMEBDtn1divu7pxmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-mulino-new-york-downtown-new-york-2?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 553,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729807, 'longitude': -73.999159},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '86 W 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['86 W 3rd St', 'New York, NY 10012']},
#    'phone': '+12126733783',
#    'display_phone': '(212) 673-3783',
#    'distance': 746.0153157529425},
#   {'id': 'T-RXDLq_VEv7s1_SooYIYQ',
#    'alias': 'osteria-57-new-york',
#    'name': 'Osteria 57',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KD1qrK51WILJwl4mwp6g1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-57-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 153,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73467, 'longitude': -73.99786},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '57 W 10th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 W 10th St', 'New York, NY 10011']},
#    'phone': '+12127770057',
#    'display_phone': '(212) 777-0057',
#    'distance': 504.02106541027865},
#   {'id': 'YoLxK5EG8UgnueKAe7hj0g',
#    'alias': 'i-sodi-new-york',
#    'name': 'I Sodi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uu4X7b8Bpd50T-lVYEVrOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/i-sodi-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 369,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7334747314453,
#     'longitude': -74.005012512207},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '105 Christopher St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['105 Christopher St', 'New York, NY 10014']},
#    'phone': '+12124145774',
#    'display_phone': '(212) 414-5774',
#    'distance': 256.65295408950766},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'alias': 'rubirosa-new-york-2',
#    'name': 'Rubirosa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 2302,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.722766, 'longitude': -73.996233},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '235 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129650500',
#    'display_phone': '(212) 965-0500',
#    'distance': 1555.7938601398134},
#   {'id': 'cGqMEMQFtkB3hIGfLy2R3A',
#    'alias': 'bar-pitti-new-york',
#    'name': 'Bar Pitti',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eUTdsZpTQhROG2acKpyj7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-pitti-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1052,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.729047, 'longitude': -74.002153},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '268 Ave Of The Americas',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['268 Ave Of The Americas', 'New York, NY 10014']},
#    'phone': '+12129823300',
#    'display_phone': '(212) 982-3300',
#    'distance': 735.3556202881094},
#   {'id': 'KpBfFpjzsGvvqAzCasVW0g',
#    'alias': 'extra-virgin-new-york',
#    'name': 'Extra Virgin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Idyk61NTgFmF2XYzdGyqxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/extra-virgin-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1263,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7353962496717,
#     'longitude': -74.0031888223197},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '259 W 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259 W 4th St', 'New York, NY 10014']},
#    'phone': '+12126919359',
#    'display_phone': '(212) 691-9359',
#    'distance': 49.08698436704141},
#   {'id': 'h9rymMeMUMOxQ9d93U0YDg',
#    'alias': 'baker-and-co-new-york',
#    'name': 'Baker & Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VVGreQXZrKQAMgGjMx66Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baker-and-co-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 637,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7313423, 'longitude': -74.0028996},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '259 Bleecker St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122551234',
#    'display_phone': '(212) 255-1234',
#    'distance': 473.21322974390597},
#   {'id': 'PajKY49h4SpvSr-TW3lwCQ',
#    'alias': 'rafele-ristorante-new-york',
#    'name': 'Rafele Ristorante',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sSRFRyAT1LAVU2j8cFjPpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rafele-ristorante-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 476,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7309471231405,
#     'longitude': -74.0041171779098},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '29 7th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12122421999',
#    'display_phone': '(212) 242-1999',
#    'distance': 512.9096805713175},
#   {'id': '_KIjhnsaui-wF9OePRZ5NA',
#    'alias': 'gottino-enoteca-e-salumeria-new-york',
#    'name': 'Gottino Enoteca e Salumeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tcRBqP31vfw7TB5BLRcfzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gottino-enoteca-e-salumeria-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 306,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7358, 'longitude': -74.00036},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '52 Greenwich Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 Greenwich Ave', 'New York, NY 10011']},
#    'phone': '+12126332590',
#    'display_phone': '(212) 633-2590',
#    'distance': 282.25454058603725},
#   {'id': '5MpWHGQ6Qc-M4q1KL_nioA',
#    'alias': 'bar-b-new-york',
#    'name': 'Bar B',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rP6Gfe33cpkYe549tj_2BQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-b-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 184,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7395804, 'longitude': -73.999118},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '84 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 7th Ave', 'New York, NY 10011']},
#    'phone': '+12122291888',
#    'display_phone': '(212) 229-1888',
#    'distance': 582.7071417430441},
#   {'id': 'vTn3ww550Rnhz9naIxtjww',
#    'alias': 'brunetti-pizza-new-york',
#    'name': 'Brunetti Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GFEmMtaYhoxsMcZZf3CjkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brunetti-pizza-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 299,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73829, 'longitude': -74.0054},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '626 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['626 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122555699',
#    'display_phone': '(212) 255-5699',
#    'distance': 332.27438394040036},
#   {'id': 'a0IET3_yCFcO36OqGSsisg',
#    'alias': 'eataly-flatiron-new-york',
#    'name': 'Eataly Flatiron',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CnTjWyLu9nEkH6BJ9LNgTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eataly-flatiron-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 5643,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74195877796, 'longitude': -73.989716662832},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '200 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 5th Ave', 'New York, NY 10010']},
#    'phone': '+12122292560',
#    'display_phone': '(212) 229-2560',
#    'distance': 1379.3308907596584},
#   {'id': 'wq43ljNSuSMG81qKHE7YpQ',
#    'alias': 'sant-ambroeus-west-village-new-york',
#    'name': 'Sant Ambroeus West Village',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FuXz9nH5jF-4igMXe4viwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sant-ambroeus-west-village-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 246,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.735428, 'longitude': -74.003142},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '259 West 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259 West 4th St', 'New York, NY 10014']},
#    'phone': '+12126049254',
#    'display_phone': '(212) 604-9254',
#    'distance': 51.76000220902864},
#   {'id': 'qrcu1K6f8WGMODdq_A8unw',
#    'alias': 'volare-restaurant-new-york',
#    'name': 'Volare Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BJ04SeEULgmOB2Hy3JDVEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/volare-restaurant-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 134,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7315434396639,
#     'longitude': -74.0006124973297},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '147 W 4th St Frnt',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 W 4th St Frnt', 'New York, NY 10012']},
#    'phone': '+12127772849',
#    'display_phone': '(212) 777-2849',
#    'distance': 517.4460042422082},
#   {'id': 'aHRcUI_UqFNV87GF7WRIDQ',
#    'alias': 'aunt-jakes-new-york-3',
#    'name': "Aunt Jake's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wVpnpN_6lwUt9BGvKlZmJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aunt-jakes-new-york-3?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 261,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.733342, 'longitude': -73.998494},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '47 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 W 8th St', 'New York, NY 10011']},
#    'phone': '+12122539333',
#    'display_phone': '(212) 253-9333',
#    'distance': 505.26247749552397},
#   {'id': 'lwfCl81r5a0mjxDNxNGC9w',
#    'alias': 'il-buco-new-york',
#    'name': 'Il Buco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Stk9ssPZ24tVQRd-Bs7gsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-buco-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 682,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72583, 'longitude': -73.99299},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '47 Bond St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 Bond St', 'New York, NY 10012']},
#    'phone': '+12125331932',
#    'display_phone': '(212) 533-1932',
#    'distance': 1412.4061047868563},
#   {'id': 'AUifp6IDKzmorCM6vY2fug',
#    'alias': 'pepe-giallo-new-york',
#    'name': 'Pepe Giallo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/17qzPvHvelVkbeSogY3Z5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pepe-giallo-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 657,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7468940064083,
#     'longitude': -74.0049896784992},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '195 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['195 10th Ave', 'New York, NY 10011']},
#    'phone': '+12122426055',
#    'display_phone': '(212) 242-6055',
#    'distance': 1265.7393419850725},
#   {'id': 'bW3mY-voyav37nU0uaLmNQ',
#    'alias': 'dante-new-york',
#    'name': 'Dante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KG1kurs7VTc48dQ-7tYGEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dante-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 366,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72879, 'longitude': -74.00165},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '79-81 Macdougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79-81 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12129825275',
#    'display_phone': '(212) 982-5275',
#    'distance': 762.2819946649194},
#   {'id': '32VbG_XgkZIuye0PV-BxaA',
#    'alias': 'zero-otto-nove-new-york-3',
#    'name': 'Zero Otto Nove',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B1rfkFnHFfmbci_miI1slw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zero-otto-nove-new-york-3?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 478,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7407551035259,
#     'longitude': -73.9914887388588},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '15 W 21st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 W 21st St', 'New York, NY 10010']},
#    'phone': '+12122420899',
#    'display_phone': '(212) 242-0899',
#    'distance': 1182.955626705623},
#   {'id': 'idxD3X7WfLFPZMoFnCRIQQ',
#    'alias': 'il-cantinori-new-york',
#    'name': 'Il Cantinori',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-LKNk4aQn4Vp83T9z1GU_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-cantinori-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 248,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7322779619352,
#     'longitude': -73.9929321762328},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '32 E 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 E 10th St', 'New York, NY 10003']},
#    'phone': '+12126736044',
#    'display_phone': '(212) 673-6044',
#    'distance': 980.2405277867384},
#   {'id': 'twHJyFgUSd7wzioKQjE7Jw',
#    'alias': 'galli-new-york-5',
#    'name': 'Galli',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NriJMGzJm4mZn-Pj2oRm3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/galli-new-york-5?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 950,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72161, 'longitude': -74.00127},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '45 Mercer St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 Mercer St', 'New York, NY 10013']},
#    'phone': '+12129669288',
#    'display_phone': '(212) 966-9288',
#    'distance': 1557.5303114483168},
#   {'id': 'kr5fRwdHtVwPPwSJxm9Fkg',
#    'alias': 'il-posto-accanto-new-york',
#    'name': 'Il Posto Accanto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nSFNU6VtjHrnQmvXVOpVDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-posto-accanto-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 233,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72238, 'longitude': -73.98403},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '190 E 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 E 2nd St', 'New York, NY 10009']},
#    'phone': '+12122283562',
#    'display_phone': '(212) 228-3562',
#    'distance': 2211.4491152109968},
#   {'id': 'Zub6WrbrS_4XMI1mPbyeiw',
#    'alias': 'panineria-italiana-new-york',
#    'name': 'Panineria Italiana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Lw5fmFzrSnGvbTLy-6zDcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panineria-italiana-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 215,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7324876186231,
#     'longitude': -73.9967531074097},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1 W 8th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 W 8th St', 'New York, NY 10011']},
#    'phone': '+19173883257',
#    'display_phone': '(917) 388-3257',
#    'distance': 679.7336420405021},
#   {'id': 'DLRbxg74oWNPQJdbSkTDxQ',
#    'alias': 'suprema-provisions-new-york',
#    'name': 'Suprema Provisions',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QnSt7_88hvVUMDMkxA1MZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suprema-provisions-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 246,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7326925, 'longitude': -74.0036155},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '305 Bleecker St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['305 Bleecker St', 'New York, NY 10014']},
#    'phone': '+16469644994',
#    'display_phone': '(646) 964-4994',
#    'distance': 317.9771693523855},
#   {'id': 'N-rwVhnEtXg8yY_TlB_KZw',
#    'alias': 'del-posto-new-york',
#    'name': 'Del Posto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JWI8PVeAGzmaNuaqUVgD9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/del-posto-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1432,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7434155953035,
#     'longitude': -74.007533013261},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '85 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 10th Ave', 'New York, NY 10011']},
#    'phone': '+12124978090',
#    'display_phone': '(212) 497-8090',
#    'distance': 931.2473713597135},
#   {'id': 'OCTiJwvjoK81WoDwsTkFvA',
#    'alias': 'paesano-of-mulberry-street-new-york',
#    'name': 'Paesano of Mulberry Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yN9ARCE3LF6u9E0yN5WpIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paesano-of-mulberry-street-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 967,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718554, 'longitude': -73.997447},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '136 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Mulberry St', 'New York, NY 10013']},
#    'phone': '+12129651188',
#    'display_phone': '(212) 965-1188',
#    'distance': 1962.8092198297409}],
#  'total': 1000,
#  'region': {'center': {'longitude': -74.00373458862305,
#    'latitude': 40.735550716411886}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'rp8S7scxOkVVeG7dNneMGQ',
#    'alias': 'l-artusi-new-york',
#    'name': "L'Artusi",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HeDloBW-SnokWblGDuPrUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-artusi-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1862,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73372, 'longitude': -74.00513},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '228 W 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 W 10th St', 'New York, NY 10014']},
#    'phone': '+12122555757',
#    'display_phone': '(212) 255-5757',
#    'distance': 235.00483236552975},
#   {'id': 'h37t9rA06Sr4EetJjKrfzw',
#    'alias': 'don-angie-new-york',
#    'name': 'Don Angie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u-XgISAco-BBpUpuFrzJwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-angie-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 356,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73778, 'longitude': -74.00197},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '103 Greenwich Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 Greenwich Ave', 'New York, NY 10014']},
#    'phone': '+12128898884',
#    'display_phone': '(212) 889-8884',
#    'distance': 287.8085574655449},
#   {'id': '16ZnHpuaaBt92XWeJHCC5A',
#    'alias': 'olio-e-piú-new-york-5',
#    'name': 'Olio e Piú',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zfMdQW5StR08SPg96JWy8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olio-e-pi%C3%BA-new-york-5?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 2328,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733826, 'longitude': -73.999852},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3 Greenwich Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Greenwich Ave', 'New York, NY 10014']},
#    'phone': '+12122436546',
#    'display_phone': '(212) 243-6546',
#    'distance': 379.20450703107264},
#   {'id': 'hdiuRS9sVZSMReZm4oV5SA',
#    'alias': 'da-andrea-new-york',
#    'name': 'Da Andrea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p_nuRaEIirVvKl55KPrzgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-andrea-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 783,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.736218, 'longitude': -73.99597},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '35 W 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 W 13th St', 'New York, NY 10011']},
#    'phone': '+12123671979',
#    'display_phone': '(212) 367-1979',
#    'distance': 658.4009812926486},
#   {'id': 'IErfGS0DASSJfYU73m0Sqg',
#    'alias': 'malatesta-trattoria-new-york',
#    'name': 'Malatesta Trattoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-5A2WyQVd3xrzudn9JBLVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/malatesta-trattoria-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1248,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73285, 'longitude': -74.00847},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '649 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['649 Washington St', 'New York, NY 10014']},
#    'phone': '+12127411207',
#    'display_phone': '(212) 741-1207',
#    'distance': 497.3612080254306},
#   {'id': 'yZJbealagfujEkgesAl2hA',
#    'alias': 'lupa-new-york',
#    'name': 'Lupa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OdUK7zgusaMmPzToZuq3tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lupa-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1546,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7276, 'longitude': -74.000045},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '170 Thompson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 Thompson St', 'New York, NY 10012']},
#    'phone': '+12129825089',
#    'display_phone': '(212) 982-5089',
#    'distance': 930.7382369526371},
#   {'id': 'ZVa3-O6LMxZXSpKG0J1h-w',
#    'alias': 'piccolo-angolo-restaurant-new-york',
#    'name': 'Piccolo Angolo Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/q536opZ7gIL0oLxztUd2Gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccolo-angolo-restaurant-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 551,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7378601855952,
#     'longitude': -74.0058052539825},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '621 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['621 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122299177',
#    'display_phone': '(212) 229-9177',
#    'distance': 310.4573489731519},
#   {'id': 'qBGKigOGn_flCx1apxPzlA',
#    'alias': 'piccola-cucina-osteria-new-york',
#    'name': 'Piccola Cucina Osteria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U9CN5QUnEAp1tHKHM8ZrXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccola-cucina-osteria-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 571,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72506, 'longitude': -74.00322},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '196 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['196 Spring St', 'New York, NY 10012']},
#    'phone': '+16464787488',
#    'display_phone': '(646) 478-7488',
#    'distance': 1171.1830140013515},
#   {'id': 'jnHbdsqlTKlPcmJ8BCP9-g',
#    'alias': 'via-carota-new-york',
#    'name': 'Via Carota',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5EHi8MhocoDkXwMtL7o_ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/via-carota-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 586,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7331, 'longitude': -74.00369},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '51 Grove St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51 Grove St', 'New York, NY 10014']},
#    'phone': '+12122551962',
#    'display_phone': '(212) 255-1962',
#    'distance': 263.993966246553},
#   {'id': 'V-FCEicobl5Su-R7EVJQNA',
#    'alias': 'la-lanterna-di-vittorio-new-york',
#    'name': 'La Lanterna Di Vittorio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fniemSih6k-Gy103nmNVxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-lanterna-di-vittorio-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1466,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73069, 'longitude': -74.00015},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '129 MacDougal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['129 MacDougal St', 'New York, NY 10012']},
#    'phone': '+19176393236',
#    'display_phone': '(917) 639-3236',
#    'distance': 617.4476178465328},
#   {'id': 'ADHX7nBixDPVlq3OXhny0g',
#    'alias': 'faiccos-italian-specialties-new-york',
#    'name': "Faicco's Italian Specialties",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ecEFegMI5jPZbSI2QnndrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/faiccos-italian-specialties-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 540,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73113, 'longitude': -74.00306},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '260 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['260 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122431974',
#    'display_phone': '(212) 243-1974',
#    'distance': 493.7443742969898},
#   {'id': '_V7YsDQ4Lb41rqfkuPzm1w',
#    'alias': 'trattoria-pesce-pasta-new-york',
#    'name': 'Trattoria Pesce Pasta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FzapSuftE8tAd9kjpMo-Rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trattoria-pesce-pasta-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 246,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73115, 'longitude': -74.00319},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '262 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['262 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12126452993',
#    'display_phone': '(212) 645-2993',
#    'distance': 489.1306142055865},
#   {'id': 'YT5Ywu9y190B4IGIlBetzA',
#    'alias': 'morandi-new-york',
#    'name': 'Morandi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vJY1QKjGtO3noWUnshjEpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morandi-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 692,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73534, 'longitude': -74.00151},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '211 Waverly Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 Waverly Pl', 'New York, NY 10014']},
#    'phone': '+12126277575',
#    'display_phone': '(212) 627-7575',
#    'distance': 196.05652023672923},
#   {'id': '6Z5OWpaeGGazJHR4LfThsw',
#    'alias': 'palma-new-york',
#    'name': 'Palma',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KRhsHF7JmChZ5xrW5owiKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/palma-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 735,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73115, 'longitude': -74.00233},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '28 Cornelia St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Cornelia St', 'New York, NY 10014']},
#    'phone': '+12126912223',
#    'display_phone': '(212) 691-2223',
#    'distance': 498.88812125626464},
#   {'id': 'XfOa_KyrV7JSFJMOKckGMg',
#    'alias': 'montes-trattoria-new-york-2',
#    'name': "Monte's Trattoria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gjCsoro5Iyw7FhIOyMDR-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montes-trattoria-new-york-2?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 356,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72959, 'longitude': -74.0011},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '97 Macdougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12122289194',
#    'display_phone': '(212) 228-9194',
#    'distance': 694.1891183931191},
#   {'id': '15k7iqFbhf4h8L01yggLqg',
#    'alias': 'song-e-napule-new-york',
#    'name': 'Song E Napule',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y9G-nheTrxSrx4Cqg0HzHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/song-e-napule-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 499,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72813, 'longitude': -74.00188},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '146 W Houston St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 W Houston St', 'New York, NY 10012']},
#    'phone': '+12125331242',
#    'display_phone': '(212) 533-1242',
#    'distance': 834.6729873886403},
#   {'id': '7_hGsGEkHrjgAiYVjrCFnw',
#    'alias': 'carbone-new-york',
#    'name': 'Carbone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IPaDl6bzctnQOM6__ibOzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carbone-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1107,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728, 'longitude': -74.0001497},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '181 Thompson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Thompson St', 'New York, NY 10012']},
#    'phone': '+12122543000',
#    'display_phone': '(212) 254-3000',
#    'distance': 892.2844648923464},
#   {'id': '5Akss-swwfyoSVeIsDBbvw',
#    'alias': 'basta-pasta-new-york',
#    'name': 'Basta Pasta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_XGks_Id3-yCUzy-Spuw-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/basta-pasta-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1447,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73881, 'longitude': -73.99407},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '37 W 17th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 W 17th St', 'New York, NY 10011']},
#    'phone': '+12123660888',
#    'display_phone': '(212) 366-0888',
#    'distance': 893.6330169566667},
#   {'id': '-hUvO0C0A-pGZdiSKvjoFw',
#    'alias': 'babbo-new-york',
#    'name': 'Babbo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q5C3VQRIzsOoCGrZvjkFHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/babbo-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 2402,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732283, 'longitude': -73.999284},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '110 Waverly Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Waverly Pl', 'New York, NY 10011']},
#    'phone': '+12127770303',
#    'display_phone': '(212) 777-0303',
#    'distance': 522.1566838589547},
#   {'id': 'o5mMVFk4Hcpk2FuKfgTgdg',
#    'alias': 'malaparte-new-york',
#    'name': 'Malaparte',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2Ikz75YSTtVvPCDuMID8bA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/malaparte-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 329,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73687, 'longitude': -74.00812},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '753 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['753 Washington St', 'New York, NY 10014']},
#    'phone': '+12122552122',
#    'display_phone': '(212) 255-2122',
#    'distance': 395.8575488921887},
#   {'id': 'Vs8kQ4R381y27AH018gLpg',
#    'alias': 'supper-new-york',
#    'name': 'Supper',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jEEH9kmoHFmyQRgXiMjFuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/supper-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1312,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7229, 'longitude': -73.98527},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '156 E 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 E 2nd St', 'New York, NY 10009']},
#    'phone': '+12124777600',
#    'display_phone': '(212) 477-7600',
#    'distance': 2097.9482060458718},
#   {'id': 'dh5r9-SbN8xJ76XvnayWLQ',
#    'alias': 'giano-restaurant-new-york',
#    'name': 'Giano Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0PrOZ5stl86k6V1SzHcjNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giano-restaurant-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 611,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7262256596862,
#     'longitude': -73.9840574049125},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '126 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 E 7th St', 'New York, NY 10009']},
#    'phone': '+12126737200',
#    'display_phone': '(212) 673-7200',
#    'distance': 1955.560551684049},
#   {'id': 'J0OeDwmh5JBhid0A5GvltA',
#    'alias': 'il-corallo-trattoria-new-york',
#    'name': 'Il Corallo Trattoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GQZVMl-a6lIpu_ZnB5xcgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-corallo-trattoria-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 970,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7262073, 'longitude': -74.0018919},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '176 Prince St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 Prince St', 'New York, NY 10012']},
#    'phone': '+12129417119',
#    'display_phone': '(212) 941-7119',
#    'distance': 1050.4775288548224},
#   {'id': 'aJJlY5xvqS180wtRIHEWqA',
#    'alias': 'cotenna-new-york',
#    'name': 'Cotenna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A9FtedBK3bJGB7t-EeclJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cotenna-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 403,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72903, 'longitude': -74.00357},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '21 Bedford St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Bedford St', 'New York, NY 10014']},
#    'phone': '+16468610175',
#    'display_phone': '(646) 861-0175',
#    'distance': 727.7166967104224},
#   {'id': 'DtnlLLvcqeEUIyZTypHnzw',
#    'alias': 'il-mulino-new-york-downtown-new-york-2',
#    'name': 'Il Mulino New York - Downtown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IR-FDmMEBDtn1divu7pxmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-mulino-new-york-downtown-new-york-2?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 553,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729807, 'longitude': -73.999159},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '86 W 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['86 W 3rd St', 'New York, NY 10012']},
#    'phone': '+12126733783',
#    'display_phone': '(212) 673-3783',
#    'distance': 746.0153157529425},
#   {'id': 'T-RXDLq_VEv7s1_SooYIYQ',
#    'alias': 'osteria-57-new-york',
#    'name': 'Osteria 57',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KD1qrK51WILJwl4mwp6g1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-57-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 153,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73467, 'longitude': -73.99786},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '57 W 10th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 W 10th St', 'New York, NY 10011']},
#    'phone': '+12127770057',
#    'display_phone': '(212) 777-0057',
#    'distance': 504.02106541027865},
#   {'id': 'YoLxK5EG8UgnueKAe7hj0g',
#    'alias': 'i-sodi-new-york',
#    'name': 'I Sodi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uu4X7b8Bpd50T-lVYEVrOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/i-sodi-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 369,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7334747314453,
#     'longitude': -74.005012512207},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '105 Christopher St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['105 Christopher St', 'New York, NY 10014']},
#    'phone': '+12124145774',
#    'display_phone': '(212) 414-5774',
#    'distance': 256.65295408950766},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'alias': 'rubirosa-new-york-2',
#    'name': 'Rubirosa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 2302,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.722766, 'longitude': -73.996233},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '235 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129650500',
#    'display_phone': '(212) 965-0500',
#    'distance': 1555.7938601398134},
#   {'id': 'cGqMEMQFtkB3hIGfLy2R3A',
#    'alias': 'bar-pitti-new-york',
#    'name': 'Bar Pitti',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eUTdsZpTQhROG2acKpyj7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-pitti-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1052,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.729047, 'longitude': -74.002153},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '268 Ave Of The Americas',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['268 Ave Of The Americas', 'New York, NY 10014']},
#    'phone': '+12129823300',
#    'display_phone': '(212) 982-3300',
#    'distance': 735.3556202881094},
#   {'id': 'KpBfFpjzsGvvqAzCasVW0g',
#    'alias': 'extra-virgin-new-york',
#    'name': 'Extra Virgin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Idyk61NTgFmF2XYzdGyqxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/extra-virgin-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1263,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7353962496717,
#     'longitude': -74.0031888223197},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '259 W 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259 W 4th St', 'New York, NY 10014']},
#    'phone': '+12126919359',
#    'display_phone': '(212) 691-9359',
#    'distance': 49.08698436704141},
#   {'id': 'h9rymMeMUMOxQ9d93U0YDg',
#    'alias': 'baker-and-co-new-york',
#    'name': 'Baker & Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VVGreQXZrKQAMgGjMx66Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baker-and-co-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 637,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7313423, 'longitude': -74.0028996},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '259 Bleecker St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122551234',
#    'display_phone': '(212) 255-1234',
#    'distance': 473.21322974390597},
#   {'id': 'PajKY49h4SpvSr-TW3lwCQ',
#    'alias': 'rafele-ristorante-new-york',
#    'name': 'Rafele Ristorante',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sSRFRyAT1LAVU2j8cFjPpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rafele-ristorante-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 476,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7309471231405,
#     'longitude': -74.0041171779098},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '29 7th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12122421999',
#    'display_phone': '(212) 242-1999',
#    'distance': 512.9096805713175},
#   {'id': '_KIjhnsaui-wF9OePRZ5NA',
#    'alias': 'gottino-enoteca-e-salumeria-new-york',
#    'name': 'Gottino Enoteca e Salumeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tcRBqP31vfw7TB5BLRcfzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gottino-enoteca-e-salumeria-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 306,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7358, 'longitude': -74.00036},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '52 Greenwich Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 Greenwich Ave', 'New York, NY 10011']},
#    'phone': '+12126332590',
#    'display_phone': '(212) 633-2590',
#    'distance': 282.25454058603725},
#   {'id': '5MpWHGQ6Qc-M4q1KL_nioA',
#    'alias': 'bar-b-new-york',
#    'name': 'Bar B',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rP6Gfe33cpkYe549tj_2BQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-b-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 184,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7395804, 'longitude': -73.999118},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '84 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 7th Ave', 'New York, NY 10011']},
#    'phone': '+12122291888',
#    'display_phone': '(212) 229-1888',
#    'distance': 582.7071417430441},
#   {'id': 'vTn3ww550Rnhz9naIxtjww',
#    'alias': 'brunetti-pizza-new-york',
#    'name': 'Brunetti Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GFEmMtaYhoxsMcZZf3CjkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brunetti-pizza-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 299,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73829, 'longitude': -74.0054},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '626 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['626 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122555699',
#    'display_phone': '(212) 255-5699',
#    'distance': 332.27438394040036},
#   {'id': 'a0IET3_yCFcO36OqGSsisg',
#    'alias': 'eataly-flatiron-new-york',
#    'name': 'Eataly Flatiron',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CnTjWyLu9nEkH6BJ9LNgTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eataly-flatiron-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 5643,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74195877796, 'longitude': -73.989716662832},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '200 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 5th Ave', 'New York, NY 10010']},
#    'phone': '+12122292560',
#    'display_phone': '(212) 229-2560',
#    'distance': 1379.3308907596584},
#   {'id': 'wq43ljNSuSMG81qKHE7YpQ',
#    'alias': 'sant-ambroeus-west-village-new-york',
#    'name': 'Sant Ambroeus West Village',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FuXz9nH5jF-4igMXe4viwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sant-ambroeus-west-village-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 246,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.735428, 'longitude': -74.003142},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '259 West 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259 West 4th St', 'New York, NY 10014']},
#    'phone': '+12126049254',
#    'display_phone': '(212) 604-9254',
#    'distance': 51.76000220902864},
#   {'id': 'qrcu1K6f8WGMODdq_A8unw',
#    'alias': 'volare-restaurant-new-york',
#    'name': 'Volare Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BJ04SeEULgmOB2Hy3JDVEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/volare-restaurant-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 134,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7315434396639,
#     'longitude': -74.0006124973297},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '147 W 4th St Frnt',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 W 4th St Frnt', 'New York, NY 10012']},
#    'phone': '+12127772849',
#    'display_phone': '(212) 777-2849',
#    'distance': 517.4460042422082},
#   {'id': 'aHRcUI_UqFNV87GF7WRIDQ',
#    'alias': 'aunt-jakes-new-york-3',
#    'name': "Aunt Jake's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wVpnpN_6lwUt9BGvKlZmJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aunt-jakes-new-york-3?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 261,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.733342, 'longitude': -73.998494},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '47 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 W 8th St', 'New York, NY 10011']},
#    'phone': '+12122539333',
#    'display_phone': '(212) 253-9333',
#    'distance': 505.26247749552397},
#   {'id': 'lwfCl81r5a0mjxDNxNGC9w',
#    'alias': 'il-buco-new-york',
#    'name': 'Il Buco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Stk9ssPZ24tVQRd-Bs7gsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-buco-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 682,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72583, 'longitude': -73.99299},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '47 Bond St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 Bond St', 'New York, NY 10012']},
#    'phone': '+12125331932',
#    'display_phone': '(212) 533-1932',
#    'distance': 1412.4061047868563},
#   {'id': 'AUifp6IDKzmorCM6vY2fug',
#    'alias': 'pepe-giallo-new-york',
#    'name': 'Pepe Giallo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/17qzPvHvelVkbeSogY3Z5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pepe-giallo-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 657,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7468940064083,
#     'longitude': -74.0049896784992},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '195 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['195 10th Ave', 'New York, NY 10011']},
#    'phone': '+12122426055',
#    'display_phone': '(212) 242-6055',
#    'distance': 1265.7393419850725},
#   {'id': 'bW3mY-voyav37nU0uaLmNQ',
#    'alias': 'dante-new-york',
#    'name': 'Dante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KG1kurs7VTc48dQ-7tYGEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dante-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 366,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72879, 'longitude': -74.00165},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '79-81 Macdougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79-81 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12129825275',
#    'display_phone': '(212) 982-5275',
#    'distance': 762.2819946649194},
#   {'id': '32VbG_XgkZIuye0PV-BxaA',
#    'alias': 'zero-otto-nove-new-york-3',
#    'name': 'Zero Otto Nove',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B1rfkFnHFfmbci_miI1slw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zero-otto-nove-new-york-3?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 478,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7407551035259,
#     'longitude': -73.9914887388588},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '15 W 21st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 W 21st St', 'New York, NY 10010']},
#    'phone': '+12122420899',
#    'display_phone': '(212) 242-0899',
#    'distance': 1182.955626705623},
#   {'id': 'idxD3X7WfLFPZMoFnCRIQQ',
#    'alias': 'il-cantinori-new-york',
#    'name': 'Il Cantinori',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-LKNk4aQn4Vp83T9z1GU_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-cantinori-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 248,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7322779619352,
#     'longitude': -73.9929321762328},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '32 E 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 E 10th St', 'New York, NY 10003']},
#    'phone': '+12126736044',
#    'display_phone': '(212) 673-6044',
#    'distance': 980.2405277867384},
#   {'id': 'twHJyFgUSd7wzioKQjE7Jw',
#    'alias': 'galli-new-york-5',
#    'name': 'Galli',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NriJMGzJm4mZn-Pj2oRm3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/galli-new-york-5?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 950,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72161, 'longitude': -74.00127},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '45 Mercer St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 Mercer St', 'New York, NY 10013']},
#    'phone': '+12129669288',
#    'display_phone': '(212) 966-9288',
#    'distance': 1557.5303114483168},
#   {'id': 'kr5fRwdHtVwPPwSJxm9Fkg',
#    'alias': 'il-posto-accanto-new-york',
#    'name': 'Il Posto Accanto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nSFNU6VtjHrnQmvXVOpVDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-posto-accanto-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 233,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72238, 'longitude': -73.98403},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '190 E 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 E 2nd St', 'New York, NY 10009']},
#    'phone': '+12122283562',
#    'display_phone': '(212) 228-3562',
#    'distance': 2211.4491152109968},
#   {'id': 'Zub6WrbrS_4XMI1mPbyeiw',
#    'alias': 'panineria-italiana-new-york',
#    'name': 'Panineria Italiana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Lw5fmFzrSnGvbTLy-6zDcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panineria-italiana-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 215,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7324876186231,
#     'longitude': -73.9967531074097},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1 W 8th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 W 8th St', 'New York, NY 10011']},
#    'phone': '+19173883257',
#    'display_phone': '(917) 388-3257',
#    'distance': 679.7336420405021},
#   {'id': 'DLRbxg74oWNPQJdbSkTDxQ',
#    'alias': 'suprema-provisions-new-york',
#    'name': 'Suprema Provisions',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QnSt7_88hvVUMDMkxA1MZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suprema-provisions-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 246,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7326925, 'longitude': -74.0036155},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '305 Bleecker St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['305 Bleecker St', 'New York, NY 10014']},
#    'phone': '+16469644994',
#    'display_phone': '(646) 964-4994',
#    'distance': 317.9771693523855},
#   {'id': 'N-rwVhnEtXg8yY_TlB_KZw',
#    'alias': 'del-posto-new-york',
#    'name': 'Del Posto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JWI8PVeAGzmaNuaqUVgD9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/del-posto-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 1432,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7434155953035,
#     'longitude': -74.007533013261},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '85 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 10th Ave', 'New York, NY 10011']},
#    'phone': '+12124978090',
#    'display_phone': '(212) 497-8090',
#    'distance': 931.2473713597135},
#   {'id': 'OCTiJwvjoK81WoDwsTkFvA',
#    'alias': 'paesano-of-mulberry-street-new-york',
#    'name': 'Paesano of Mulberry Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yN9ARCE3LF6u9E0yN5WpIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paesano-of-mulberry-street-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#    'review_count': 967,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718554, 'longitude': -73.997447},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '136 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Mulberry St', 'New York, NY 10013']},
#    'phone': '+12129651188',
#    'display_phone': '(212) 965-1188',
#    'distance': 1962.8092198297409}],
#  'total': 1000,
#  'region': {'center': {'longitude': -74.00373458862305,
#    'latitude': 40.735550716411886}}}

# %% [markdown]
# Using one of the methods above load the response data and assign it to a variable `data`.

# %%
data = response.json()

# %%
What are the keys in this dictionary and the datatypes of their values.
# Out:
#   File "<ipython-input-97-2cba7e6cfbf7>", line 1
#     What are the keys in this dictionary and the datatypes of their values.
#          ^
# SyntaxError: invalid syntax

# %%
# your code here
for key in data.keys():
    print(key)
 #Use standard dictionary formatting
    print(type(data[key])) #What type is it?
# Out:
# businesses
# <class 'list'>
# total
# <class 'int'>
# region
# <class 'dict'>

# %% [markdown]
# How many results did our query return?

# %%
data['total']
# Out:
# 1000

# %% [markdown]
# How many businesses were returned from the API call?

# %%
len(data['businesses'])
# Out:
# 50

# %% [markdown]
# ### Parsing the Results
#
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a list with the name, display_address, and one other data point of your choice. First we want to assign one of the businesses to the `business` variable. Once we cna properly parse oonne business  we can use a loop to do them all.

# %%
business = data['businesses'][0]

# %%
business
# Out:
# {'id': 'rp8S7scxOkVVeG7dNneMGQ',
#  'alias': 'l-artusi-new-york',
#  'name': "L'Artusi",
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HeDloBW-SnokWblGDuPrUQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/l-artusi-new-york?adjust_creative=0RHbihxg1H8-FtXWdWRtfQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0RHbihxg1H8-FtXWdWRtfQ',
#  'review_count': 1862,
#  'categories': [{'alias': 'italian', 'title': 'Italian'},
#   {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.73372, 'longitude': -74.00513},
#  'transactions': ['delivery', 'pickup'],
#  'price': '$$$',
#  'location': {'address1': '228 W 10th St',
#   'address2': '',
#   'address3': '',
#   'city': 'New York',
#   'zip_code': '10014',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['228 W 10th St', 'New York, NY 10014']},
#  'phone': '+12122555757',
#  'display_phone': '(212) 255-5757',
#  'distance': 235.00483236552975}

# %% [markdown]
# Rember we want the following pieces of information:
# name, display_address, and one other data point of your choice

# %%
biz_tuple = (business['name'], 
            business['location']['display_address'][0], 
            business['rating'])

# %%
biz_tuple
# Out:
# ("L'Artusi", '228 W 10th St', 4.5)

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(list_of_data):
    # create a container to hold our parsed data
    parsed_data = []
    
    # loop through our business and parse each individual business
    for business in list_of_data:
      
        biz_tuple = [business['name'], business['location']['display_address'][0], business['rating']]
    # in the loop, add each individual parsed  business to our data container
        parsed_data.append(biz_tuple)

    # return the container with all of the parsed results
    return parsed_data

# %%
parse_data(data['businesses'])
# Out:
# [["L'Artusi", '228 W 10th St', 4.5],
#  ['Don Angie', '103 Greenwich Ave', 4.5],
#  ['Olio e Piú', '3 Greenwich Ave', 4.5],
#  ['Da Andrea', '35 W 13th St', 4.0],
#  ['Malatesta Trattoria', '649 Washington St', 4.0],
#  ['Lupa', '170 Thompson St', 4.0],
#  ['Piccolo Angolo Restaurant', '621 Hudson St', 4.0],
#  ['Piccola Cucina Osteria', '196 Spring St', 4.5],
#  ['Via Carota', '51 Grove St', 4.0],
#  ['La Lanterna Di Vittorio', '129 MacDougal St', 4.0],
#  ["Faicco's Italian Specialties", '260 Bleecker St', 4.5],
#  ['Trattoria Pesce Pasta', '262 Bleecker St', 4.0],
#  ['Morandi', '211 Waverly Pl', 3.5],
#  ['Palma', '28 Cornelia St', 4.0],
#  ["Monte's Trattoria", '97 Macdougal St', 4.0],
#  ['Song E Napule', '146 W Houston St', 4.5],
#  ['Carbone', '181 Thompson St', 4.0],
#  ['Basta Pasta', '37 W 17th St', 4.0],
#  ['Babbo', '110 Waverly Pl', 4.0],
#  ['Malaparte', '753 Washington St', 4.0],
#  ['Supper', '156 E 2nd St', 4.0],
#  ['Giano Restaurant', '126 E 7th St', 4.5],
#  ['Il Corallo Trattoria', '176 Prince St', 4.0],
#  ['Cotenna', '21 Bedford St', 4.0],
#  ['Il Mulino New York - Downtown', '86 W 3rd St', 4.0],
#  ['Osteria 57', '57 W 10th St', 4.5],
#  ['I Sodi', '105 Christopher St', 3.5],
#  ['Rubirosa', '235 Mulberry St', 4.5],
#  ['Bar Pitti', '268 Ave Of The Americas', 3.5],
#  ['Extra Virgin', '259 W 4th St', 3.5],
#  ['Baker & Co', '259 Bleecker St', 4.0],
#  ['Rafele Ristorante', '29 7th Ave S', 4.0],
#  ['Gottino Enoteca e Salumeria', '52 Greenwich Ave', 4.0],
#  ['Bar B', '84 7th Ave', 4.5],
#  ['Brunetti Pizza', '626 Hudson St', 4.5],
#  ['Eataly Flatiron', '200 5th Ave', 4.0],
#  ['Sant Ambroeus West Village', '259 West 4th St', 3.5],
#  ['Volare Restaurant', '147 W 4th St Frnt', 4.5],
#  ["Aunt Jake's", '47 W 8th St', 4.0],
#  ['Il Buco', '47 Bond St', 4.0],
#  ['Pepe Giallo', '195 10th Ave', 4.0],
#  ['Dante', '79-81 Macdougal St', 4.0],
#  ['Zero Otto Nove', '15 W 21st St', 4.0],
#  ['Il Cantinori', '32 E 10th St', 4.0],
#  ['Galli', '45 Mercer St', 4.0],
#  ['Il Posto Accanto', '190 E 2nd St', 4.5],
#  ['Panineria Italiana', '1 W 8th St', 4.0],
#  ['Suprema Provisions', '305 Bleecker St', 4.0],
#  ['Del Posto', '85 10th Ave', 4.0],
#  ['Paesano of Mulberry Street', '136 Mulberry St', 4.0]]
